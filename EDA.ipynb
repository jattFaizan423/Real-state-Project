# %% [markdown]
# <a href="https://colab.research.google.com/github/jattFaizan423/Real-state-Project/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('/content/F-E + gurgaon_properties_cleaned_v2.csv')

# %%
df.head()
# Out:
#   property_type                              society      sector  price  \
# 0         house                          independent   sector 43   5.25
# 1         house  international city by sobha phase 1  sector 109   6.10
# 2          flat                    unitech sunbreeze   sector 69   0.74
# 3          flat                      pareena mi casa   sector 68   1.90
# 4          flat                   godrej nature plus   sector 33   1.40
#
#    price_per_sqft    area                                  areaWithType  \
# 0         27132.0  1935.0                   Plot area 215(179.77 sq.m.)
# 1         25103.0  2430.0                   Plot area 270(225.75 sq.m.)
# 2          5500.0  1345.0        Super Built up area 1337(124.21 sq.m.)
# 3          9227.0  2059.0              Carpet area: 2059 (191.29 sq.m.)
# 4         15124.0   926.0  Super Built up area 145Carpet area: 86 sq.m.
#
#    bedRoom  bathroom balcony  floorNum         facing       agePossession  \
# 0        4         4       2       2.0  not available        Old Property
# 1        5         6      3+       2.0  not available      Moderately Old
# 2        3         3       1      10.0  not available  Under Construction
# 3        3         3      3+       1.0  not available  Under Construction
# 4        3         2      3+      20.0  not available        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN         1935.0          NaN           1             1
# 1                  NaN         2430.0          NaN           0             1
# 2               1337.0            NaN          NaN           0             1
# 3                  NaN            NaN       2059.0           0             1
# 4                145.0            NaN         86.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            80
# 1           0           0       0                1            30
# 2           0           0       0                1            60
# 3           0           0       0                1            49
# 4           0           0       0                1            70

# %%
df.shape
# Out:
# (3802, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3802 entries, 0 to 3801
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3802 non-null   object
#  1   society              3801 non-null   object
#  2   sector               3802 non-null   object
#  3   price                3784 non-null   float64
#  4   price_per_sqft       3784 non-null   float64
#  5   area                 3784 non-null   float64
#  6   areaWithType         3802 non-null   object
#  7   bedRoom              3802 non-null   int64
#  8   bathroom             3802 non-null   int64
#  9   balcony              3802 non-null   object
#  10  floorNum             3783 non-null   float64
#  11  facing               3802 non-null   object
#  12  agePossession        3802 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1732 non-null   float64
#  15  carpet_area          1944 non-null   float64
#  16  study room           3802 non-null   int64
#  17  servant room         3802 non-null   int64
#  18  store room           3802 non-null   int64
#  19  pooja room           3802 non-null   int64
#  20  others               3802 non-null   int64
#  21  furnishing_type      3802 non-null   int64
#  22  luxury_score         3802 non-null   int64
# dtypes: float64(7), int64(9), object(7)
# memory usage: 683.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(126)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#   property_type                              society      sector  price  \
# 0         house                          independent   sector 43   5.25
# 1         house  international city by sobha phase 1  sector 109   6.10
# 2          flat                    unitech sunbreeze   sector 69   0.74
# 3          flat                      pareena mi casa   sector 68   1.90
# 4          flat                   godrej nature plus   sector 33   1.40
#
#    price_per_sqft    area                                  areaWithType  \
# 0         27132.0  1935.0                   Plot area 215(179.77 sq.m.)
# 1         25103.0  2430.0                   Plot area 270(225.75 sq.m.)
# 2          5500.0  1345.0        Super Built up area 1337(124.21 sq.m.)
# 3          9227.0  2059.0              Carpet area: 2059 (191.29 sq.m.)
# 4         15124.0   926.0  Super Built up area 145Carpet area: 86 sq.m.
#
#    bedRoom  bathroom balcony  floorNum         facing       agePossession  \
# 0        4         4       2       2.0  not available        Old Property
# 1        5         6      3+       2.0  not available      Moderately Old
# 2        3         3       1      10.0  not available  Under Construction
# 3        3         3      3+       1.0  not available  Under Construction
# 4        3         2      3+      20.0  not available        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN         1935.0          NaN           1             1
# 1                  NaN         2430.0          NaN           0             1
# 2               1337.0            NaN          NaN           0             1
# 3                  NaN            NaN       2059.0           0             1
# 4                145.0            NaN         86.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            80
# 1           0           0       0                1            30
# 2           0           0       0                1            60
# 3           0           0       0                1            49
# 4           0           0       0                1            70

# %% [markdown]
# # **Uni Variate Analysis**

# %% [markdown]
# # **1. property_type column**

# %%
df['property_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='property_type'>

# %% [markdown]
# # **Observations**
# **1. Flats are in majority(75 percent) and there are less number of houses(~25 percent)**
#
# **2. No missing values**

# %% [markdown]
# # **2. society**

# %%
df['society'].value_counts().shape
# Out:
# (676,)

# %%
df['society'].value_counts()
# Out:
# society
# independent                                          486
# tulip violet                                          75
# ss the leaf                                           73
# shapoorji pallonji joyville gurugram                  42
# dlf new town heights                                  42
# signature global park                                 35
# shree vardhman victoria                               34
# emaar mgf emerald floors premier                      32
# dlf the ultima                                        31
# smart world orchard                                   31
# paras dews                                            31
# m3m woodshire                                         30
# dlf regal gardens                                     30
# shree vardhman flora                                  29
# smart world gems                                      28
# la vida by tata housing                               28
# signature global solera                               27
# godrej nature plus                                    27
# bptp terra                                            25
# experion the heartsong                                24
# emaar gurgaon greens                                  24
# tata primanti                                         24
# vatika gurgaon                                        24
# bestech park view residency                           22
# eldeco accolade                                       22
# emaar palm gardens                                    22
# experion windchants                                   22
# m3m heights                                           21
# ats triumph                                           21
# rof ananda                                            21
# sobha city                                            20
# sare crescent parc                                    19
# sare homes                                            19
# vipul tatvam villa                                    19
# indiabulls centrum park                               19
# godrej                                                19
# international city by sobha phase 2                   19
# ats tourmaline                                        18
# chd avenue                                            18
# antriksh heights                                      18
# ambience creacions                                    18
# m3m skywalk                                           18
# mapsko mount ville                                    18
# m3m golfestate                                        17
# emaar mgf marbella                                    17
# hcbs sports ville                                     17
# conscient heritage max                                17
# gls arawali homes                                     16
# m3m merlin                                            16
# vatika the seven lamps                                15
# godrej summit                                         15
# bestech park view grand spa                           15
# emaar mgf the palm drive                              15
# pareena coban residences                              15
# international city by sobha phase 1                   15
# supertech araville                                    15
# ireo victory valley                                   15
# dlf the skycourt                                      15
# ireo skyon                                            14
# bestech park view ananda                              14
# imperia the esfera                                    14
# puri diplomatic greens                                14
# godrej oasis                                          14
# corona optus                                          14
# orchid petals                                         14
# the close north                                       13
# ramsons kshitij                                       13
# ansal heights 86                                      13
# puri emerald bay                                      13
# indiabulls enigma                                     13
# umang monsoon breeze                                  13
# umang winter hills                                    13
# dlf the primus                                        13
# ats kocoon                                            13
# unitech uniworld resorts                              12
# mvn athens                                            12
# central park flower valley                            12
# ireo the corridors                                    12
# breez global heights                                  11
# dlf city plots phase 2                                11
# sbtl caladium                                         11
# adani m2k oyster grande                               11
# bestech park view sanskruti                           11
# alpha corp gurgaonone                                 11
# tarc maceo                                            11
# raheja vedaanta                                       11
# godrej aria                                           11
# unitech espace                                        11
# dlf city plots                                        11
# pyramid urban homes 2                                 10
# signature global synera                               10
# pivotal devaan                                        10
# m3m soulitude                                         10
# dlf regency park                                      10
# capital residences 360                                10
# breez global hill view                                 9
# aipl the peaceful homes                                9
# godrej air                                             9
# bestech park view city                                 9
# pareena mi casa                                        9
# vatika city                                            9
# emaar mgf palm hills                                   9
# bptp astaire gardens                                   9
# parsvnath green ville                                  9
# signature global city                                  8
# not applicable                                         8
# sare crescent parc royal greens phase 1                8
# microtek greenburg                                     8
# zara aavaas                                            8
# gls avenue 51                                          8
# ild greens                                             8
# vatika lifestyle homes                                 8
# orris aster court premier                              8
# birla navya                                            8
# the lions cghs                                         8
# bptp visionnaire                                       8
# ss                                                     8
# bestech altura                                         8
# m3m capital                                            8
# sushant lok 1 builder floors                           7
# aipl zen residences                                    7
# hero homes                                             7
# ramprastha the edge towers                             7
# avl 36 gurgaon                                         7
# trisara our homes 3                                    7
# uppal southend                                         7
# emaar digihomes                                        7
# ireo the grand arch                                    7
# m3m skycity                                            7
# satya the hermitage                                    7
# orris carnation residency                              7
# tulip ivory                                            7
# vipul lavanya                                          7
# signature andour heights                               7
# bestech park view spa next                             6
# mapsko casa bella                                      6
# hsiidc sidco aravali                                   6
# ashiana anmol                                          6
# sidhartha ncr one phase                                6
# pioneer araya                                          6
# suncity vatsal valley                                  6
# mapsko royale ville                                    6
# kiran residency                                        6
# ansal housing highland park                            6
# eldeco mansionz                                        6
# signature global city 92                               6
# ansals palam vihar                                     6
# emaar imperial gardens                                 6
# sare green parc phase 3                                6
# greenopolis                                            6
# signature global park 4                                6
# ashiana mulberry                                       6
# supertech hues                                         6
# m3m sierra 68                                          6
# pyramid urban                                          6
# parsvnath exotica                                      6
# signature global city 63a                              5
# ireo uptown                                            5
# vatika city homes                                      5
# signature the roselia                                  5
# emaar mgf emerald estate                               5
# conscient elevate                                      5
# central park flower valley aqua front towers           5
# housing board colony                                   5
# signature global city 81                               5
# m3m the marina                                         5
# central park resorts                                   5
# pareena laxmi apartments                               5
# dlf the arbour                                         5
# godrej habitat                                         5
# pioneer park                                           5
# assotech blith                                         5
# green court                                            5
# vatika india next                                      5
# signature global orchard avenue                        5
# dlf city phase 1                                       5
# spaze privy                                            5
# adani brahma samsara vilasa                            5
# nul                                                    5
# dlf park place                                         5
# signature global city 37d ph 2                         4
# unitech uniworld gardens                               4
# godrej frontier                                        4
# ansal api esencia                                      4
# apna enclave                                           4
# malibu towne                                           4
# kendriya vihar                                         4
# ansal sushant lok plots                                4
# palam vihar extension west zone rwa                    4
# ardee city                                             4
# afnhb jalvayu vihar                                    4
# ats marigold                                           4
# ramprastha primera                                     4
# godrej icon                                            4
# emaar palm heights                                     4
# prime habitat                                          4
# tata gurgaon gateway                                   4
# ramprastha skyz                                        4
# krisumi waterfall residences                           4
# corona gracieux                                        4
# hsiidc sidco shivalik apartments                       4
# vatika independent floors                              4
# unitech aspen greens                                   4
# signature global the millennia                         4
# unitech fresco                                         4
# signature global grand iva                             4
# dlf city plots phase 3                                 4
# tulip monsella                                         4
# lotus homz                                             4
# raheja navodaya                                        4
# signature the serenas                                  4
# silverglades the melia                                 4
# orris aster court                                      4
# bptp pedestal                                          4
# ss the coralwood                                       4
# eros rosewood city                                     3
# spaze privy at                                         3
# suncity platinum towers                                3
# dlf express greens                                     3
# deepak minda                                           3
# raheja sampada                                         3
# eros rosewood villas                                   3
# ild grand                                              3
# railway officers rpf society                           3
# pyramid elite                                          3
# signature global solera 2                              3
# raheja revanta                                         3
# ss aaron ville                                         3
# essel towers                                           3
# unitech nirvana birch court                            3
# shri ram apartments                                    3
# chintels paradiso                                      3
# raheja atharva                                         3
# pivotal riddhi siddhi                                  3
# tulip lemon                                            3
# suncity avenue 76                                      3
# shree arihant apartment                                3
# sector 14 rwa                                          3
# shri banke bihari society                              3
# apex our homes                                         3
# paras quartier                                         3
# sare green parc                                        3
# mahindra aura                                          3
# piedmont taksila heights                               3
# my home                                                3
# sidhartha ncr one                                      3
# ambience lagoon                                        3
# unitech the residences                                 3
# valley view estate                                     3
# ansal heights                                          3
# vatika sovereign park                                  3
# krrish provence estate                                 3
# sidhartha ncr greens                                   3
# ansals florence villa                                  3
# tulip purple                                           3
# unitech vistas                                         3
# tulip white                                            3
# aipl club residences                                   3
# dlf royalton tower                                     3
# adani aangan arcade                                    3
# dlf the grove                                          3
# sare petioles                                          3
# sunischit apartments                                   3
# ss hibiscus                                            3
# vatika xpressions                                      3
# satya element one                                      3
# smriti apartment                                       3
# krrish florence estate                                 3
# vatika signature villas                                3
# sare green parc 2                                      3
# spaze privvy the address                               3
# guru gram haryana cghs                                 3
# whiteland blissville                                   3
# unitech sunbreeze                                      3
# sukhshanti apartment                                   2
# ss residency                                           2
# brisk lumbini terrace homes                            2
# professors enclave cghs                                2
# bhagwati sadan                                         2
# central park 2 bellevue                                2
# raheja vanya                                           2
# dlf carlton estate                                     2
# m3m latitude                                           2
# cghs airport apartment                                 2
# vatika emilia floors                                   2
# project mianwali colony                                2
# suposhaa smartworld orchard                            2
# godrej meridien                                        2
# luxury dlf city floors                                 2
# iffco nagar and 17b rwa                                2
# park royal apartment                                   2
# vatika sovereign next                                  2
# sector 38 rwa                                          2
# bptp mansions park prime                               2
# rof aalayas                                            2
# orchid island                                          2
# viridian the plaza 106                                 2
# the penthouses at the hibiscus                         2
# dlf belvedere towers                                   2
# suncity avenue                                         2
# mapsko paradise                                        2
# signature global the millennia 3                       2
# rwa sector 46                                          2
# suncity essel towers                                   2
# puri the aravallis                                     2
# mahindra luminare                                      2
# huda ashok vihar phase                                 2
# suncity heights                                        2
# bptp freedom park life                                 2
# bhim garh kheri                                        2
# unitech escape                                         2
# dlf the crest                                          2
# adani aangan galleria                                  2
# emaar emerald hills                                    2
# tulip orange                                           2
# m3m urbana                                             2
# ramprastha the atrium                                  2
# sapphire eighty three                                  2
# vatika inxt floors                                     2
# ramprastha city                                        2
# project housing board colony                           2
# emaar the palm springs                                 2
# emaar mgf emerald floors                               2
# oriental valley chs                                    2
# pioneer urban presidia                                 2
# godrej nature plus serenity                            2
# maxworth city residences                               2
# vipul belmonte                                         2
# emaar mgf the enclave                                  2
# suncity township                                       2
# unitech deerwood chase                                 2
# tulip petals                                           2
# paras irene                                            2
# unitech greenwood city                                 2
# green campus chs                                       2
# global hill view                                       2
# conscient habitat                                      2
# nirvana cedar crest                                    2
# mittal surya vihar                                     2
# shivpuri                                               2
# dhoot time residency                                   2
# palam vihar society                                    2
# tulip yellow                                           2
# jammu and kashmir bank employees cghs                  2
# vipul world                                            2
# bestech spa signature                                  2
# the close south                                        2
# central park flower valley cerise floors               2
# ss almeria                                             2
# ansal sushant residency                                2
# nbcc heights                                           2
# m3m sky lofts                                          2
# rattan garden                                          2
# m3m ikonic                                             2
# dlf the icon                                           2
# dlf the belaire                                        2
# tulsiani easy in homes                                 2
# sahara grace                                           2
# unitech palms south city 1                             2
# tulip leaf                                             2
# elan the presidential                                  2
# residency grand                                        2
# siddhartha apartment                                   2
# 4s aradhya homes                                       2
# emaar mgf palm studios                                 2
# today callidora                                        2
# awho shanti vihar                                      2
# ansal api celebrity suites                             2
# shreeram apartment ii                                  1
# irwo westend towers                                    1
# supertech basera                                       1
# allure homes                                           1
# ashok vihar phase 2                                    1
# godrej summit premia towers                            1
# chintamani                                             1
# huda housing board colony                              1
# new colony, gurgaon                                    1
# om appartments                                         1
# siddhi vinayak apartments                              1
# dlf floors phase 3                                     1
# adani brahma samsara                                   1
# essel tower                                            1
# ansal api sushant estate                               1
# bestech park view aindependentda                       1
# ansal maple crescent                                   1
# surendra homes dayaindependentd colony                 1
# pooja apartment                                        1
# sanskriti apartments                                   1
# woodstock floors                                       1
# mian wali                                              1
# aipl peaceful homes                                    1
# sonata group housing gh 24                             1
# 511 sarahah tower                                      1
# malibu towers                                          1
# bajrang apartments                                     1
# grover homes sec 4                                     1
# dlf gardencity enclave                                 1
# vipul world floors                                     1
# ganpati heights apartment                              1
# .                                                      1
# karmyogi apartment                                     1
# shyam apartment                                        1
# imt view society                                       1
# rail vihar cghs                                        1
# elan mercado                                           1
# aditya apartment                                       1
# vatika boulevard residences and heights                1
# lavanya apartments                                     1
# shyam sadan                                            1
# the rama apartment cghs                                1
# jmd gardens                                            1
# the roselia 2                                          1
# ansal maple heights                                    1
# smart world one dxp                                    1
# raheja vedas                                           1
# rk excelo                                              1
# tashee capital gateway                                 1
# bhawna cghs                                            1
# czar mahira homes 63a                                  1
# chanderlok society                                     1
# ansal harmony homes                                    1
# the castle society                                     1
# arjun marg/ sector- 26 phase- 1/ golf course road      1
# belgravia resort residences                            1
# mrg skyline                                            1
# rattan vihar rajendra park                             1
# parkwood westend                                       1
# prem kunj                                              1
# ashok vihar phase iii extension                        1
# breez global heights 88a                               1
# pivotal devaan apartments                              1
# laxmi pareena                                          1
# central park resort belgravia residences               1
# dlf trinity towers                                     1
# nagata group housing society                           1
# naman residency                                        1
# huda plots                                             1
# the khushboo cooperative housing society ltd           1
# dlf wellington estate                                  1
# apex builders                                          1
# eros wembley estate                                    1
# city heights                                           1
# rajendra park gurgaon                                  1
# shree balaji appartment                                1
# dlf garden city floors                                 1
# shivaji nagar residential                              1
# om apartment dayanand colony                           1
# imperia aashiyara                                      1
# global height                                          1
# ansal sushant lok ci                                   1
# millenium bajrang society                              1
# m m residency, krishna colony, gurgaon                 1
# bsf chs                                                1
# huda housing board society                             1
# emaar mgf palm terraces select                         1
# emaar mgf palm terraces                                1
# supertech new soft launch                              1
# aipl joy square                                        1
# dnha cghs                                              1
# bhim nagar society                                     1
# vatika seven elements                                  1
# saksham welfare association                            1
# house number b-34                                      1
# proxima tower                                          1
# wings apartment                                        1
# shyamkunj ashok vihar pahse 2                          1
# spire woods now ananda by alpha corp                   1
# kibithu villas                                         1
# senate court                                           1
# new sathi apartments                                   1
# samadhan shri kamal cghs                               1
# housing apna enclave                                   1
# ild grand centra                                       1
# madhur jeevan apartments                               1
# smartworld one dxp                                     1
# mittal cosmos executive apartments                     1
# imperia elvedor                                        1
# signature global superbia                              1
# emaar the palm drive                                   1
# whiteland  the aspen                                   1
# ansal sushant lok                                      1
# surya vihar rwa                                        1
# park view apartments                                   1
# bptp park generations                                  1
# dlf city plots phase 4                                 1
# ambience caitriona                                     1
# bhemerlei                                              1
# ansal api spanish court                                1
# the arzoo cghs                                         1
# u block dlf phase 3 road no 21                         1
# lotus elise                                            1
# vatika iris floors                                     1
# dlf exclusive floors                                   1
# ramshanti cooperative society                          1
# dlf pink town house                                    1
# baani city center                                      1
# ashiana apartment                                      1
# ninex city                                             1
# unitech south city                                     1
# whiteland the aspen                                    1
# raj villas                                             1
# ompee k s residency                                    1
# lord krishna                                           1
# unitech uniworld city                                  1
# m3m one key resiments                                  1
# sai kripa floors 5                                     1
# vidya apartment                                        1
# bhim nagar, sector 6                                   1
# ansal                                                  1
# kashish manor one                                      1
# the serenas                                            1
# huda                                                   1
# ss radiance residency                                  1
# ganpati apartment  2, laxman vihar phase 1             1
# m3m golf hills phase 1                                 1
# shree krishna homes                                    1
# unitech harmony                                        1
# unitech south park                                     1
# micasa sec 68                                          1
# cloudnine cottages                                     1
# lig flat                                               1
# conscient one                                          1
# ramson kshitij sec-95 gurugram                         1
# pgr shree kripaluji apartment                          1
# ansals highland park                                   1
# experion heartsong                                     1
# dlf alameda                                            1
# vasant appartments                                     1
# professional society                                   1
# m3m crown                                              1
# smartworld 1dxp                                        1
# la lagune                                              1
# milan cghs 9                                           1
# the nav manesar apartment                              1
# aardhya homesh                                         1
# shapoorji pallonji joyville                            1
# laxmi apartment sector 99a gurgaon                     1
# takshila heights sector 37 c                           1
# denso haryana housing society                          1
# dnha group housing society                             1
# south city 1 floors                                    1
# dlf south city 1                                       1
# huda sector-56 gurgaon                                 1
# project krishna colony                                 1
# signature signum 95a                                   1
# nirvana country                                        1
# huda flats                                             1
# the new crpf apartments                                1
# adarsh nagar                                           1
# kamroon court                                          1
# unitech the palms                                      1
# krishna appartment                                     1
# on request                                             1
# beverley park 1                                        1
# uphaar residency 2                                     1
# landmark house                                         1
# the laburnum                                           1
# raheja atlantis                                        1
# vatika sovereign next sector-82 a gurgaon              1
# ansal estella                                          1
# sector 15 part 2 rwa                                   1
# laxmi garden sector-11                                 1
# prasha apartments                                      1
# smart world one                                        1
# raheja teachers apartments                             1
# floor wise designer kothi                              1
# ansal height 86                                        1
# kanchanjanga tower                                     1
# cghs hewo apartments                                   1
# maruti kunj                                            1
# millenia                                               1
# dlf icon                                               1
# maa bhagwati residency                                 1
# saan verdante                                          1
# dlf ridgewood estate                                   1
# elevate                                                1
# rose apartment                                         1
# kothi                                                  1
# anamika enclave                                        1
# signature global infinity mall                         1
# maruti vihar                                           1
# adani oyster greens                                    1
# sneh vihar                                             1
# raheja the vedaanta floors                             1
# green homes                                            1
# pyramid pride                                          1
# awho sispal vihar                                      1
# private house                                          1
# sobha smriti apartments                                1
# breeze global heights                                  1
# kw royal court                                         1
# ansals duplex flat                                     1
# espire south                                           1
# satya the legend                                       1
# madan puri                                             1
# bptp amstoria                                          1
# the pearl apartmen                                     1
# emaar palm premier                                     1
# ansal sushant lok 2                                    1
# shree kirpalu gi sector 52                             1
# signature global rosellia                              1
# aindependentt raj estates                              1
# meditech apartment                                     1
# sbr apartment                                          1
# silverglades hightown residences                       1
# park view apartment                                    1
# sbr minda sec-1 imt manesar                            1
# rwa                                                    1
# signature global orchard avenue 2                      1
# navjyoti apartment                                     1
# eden landmark                                          1
# cghs vidya enclave                                     1
# m3m golf hills                                         1
# surendra avenue 69                                     1
# supertech hilltown                                     1
# the center court                                       1
# apartment                                              1
# ashok vihar phase 3 gurgaon                            1
# cghs rail vihar                                        1
# uphaar homes                                           1
# city shri ram apartments 1                             1
# dlf city plot phase 4                                  1
# citizen apartment                                      1
# divya apartments                                       1
# ansal florence super                                   1
# nitin vihar                                            1
# raisina residency                                      1
# the cocoon                                             1
# friends apartment                                      1
# huda floor                                             1
# maruti vihar colony                                    1
# m3m antalya hills                                      1
# nirmal enclave, maruti kunj road                       1
# shree vardhman mantra                                  1
# independent house sector 45                            1
# g l s arawali homes                                    1
# m3m the tree of life                                   1
# hector trimurti heights                                1
# shri shyam residency                                   1
# ansal celebrity homes                                  1
# uphar lakshya homes                                    1
# ace palm floors                                        1
# sidhivinayak apartments                                1
# unitech heritage city                                  1
# spectrum centre                                        1
# huda plot sector 38                                    1
# anshul                                                 1
# jacob pura                                             1
# row house                                              1
# sbr minda sec 1 imt manesar                            1
# ansal plaza                                            1
# dlf 76                                                 1
# cancon enclave                                         1
# mrg world ultimus                                      1
# sector 57 huda                                         1
# mariners home                                          1
# bhawani enclave                                        1
# sanskriti apartment                                    1
# dlf beverly park                                       1
# ss omnia                                               1
# sheetla enclave                                        1
# landmark the residency                                 1
# rk tower                                               1
# antriksh green                                         1
# kamal residence                                        1
# raheja maheshwara                                      1
# radhakrishna society                                   1
# shri balaji apartment                                  1
# ramprasta awho                                         1
# godrej 101, sector 79                                  1
# jacobpura                                              1
# earth copia                                            1
# dlf city plot phase 3                                  1
# sagar apartment                                        1
# swarn jayanti cghs                                     1
# the crew bos chs manesar                               1
# Name: count, dtype: int64

# %%
df[df['society'] != 'independent']['society'].value_counts(normalize=True).cumsum().head(75)
# Out:
# society
# tulip violet                            0.023518
# ss the leaf                             0.046410
# shapoorji pallonji joyville gurugram    0.059580
# dlf new town heights                    0.072750
# signature global park                   0.083725
# shree vardhman victoria                 0.094387
# emaar mgf emerald floors premier        0.104421
# dlf the ultima                          0.114142
# paras dews                              0.123863
# smart world orchard                     0.133584
# m3m woodshire                           0.142992
# dlf regal gardens                       0.152399
# shree vardhman flora                    0.161493
# smart world gems                        0.170273
# la vida by tata housing                 0.179053
# signature global solera                 0.187520
# godrej nature plus                      0.195986
# bptp terra                              0.203826
# experion the heartsong                  0.211352
# tata primanti                           0.218877
# emaar gurgaon greens                    0.226403
# vatika gurgaon                          0.233929
# eldeco accolade                         0.240828
# emaar palm gardens                      0.247727
# bestech park view residency             0.254625
# experion windchants                     0.261524
# m3m heights                             0.268109
# rof ananda                              0.274694
# ats triumph                             0.281279
# sobha city                              0.287551
# indiabulls centrum park                 0.293509
# sare crescent parc                      0.299467
# sare homes                              0.305425
# godrej                                  0.311383
# international city by sobha phase 2     0.317341
# vipul tatvam villa                      0.323299
# ats tourmaline                          0.328943
# chd avenue                              0.334588
# antriksh heights                        0.340232
# ambience creacions                      0.345876
# m3m skywalk                             0.351521
# mapsko mount ville                      0.357165
# hcbs sports ville                       0.362496
# emaar mgf marbella                      0.367827
# m3m golfestate                          0.373158
# conscient heritage max                  0.378489
# m3m merlin                              0.383506
# gls arawali homes                       0.388523
# godrej summit                           0.393227
# pareena coban residences                0.397930
# bestech park view grand spa             0.402634
# emaar mgf the palm drive                0.407338
# international city by sobha phase 1     0.412041
# ireo victory valley                     0.416745
# dlf the skycourt                        0.421449
# supertech araville                      0.426152
# vatika the seven lamps                  0.430856
# ireo skyon                              0.435246
# orchid petals                           0.439636
# bestech park view ananda                0.444026
# puri diplomatic greens                  0.448416
# imperia the esfera                      0.452807
# godrej oasis                            0.457197
# corona optus                            0.461587
# ats kocoon                              0.465663
# ramsons kshitij                         0.469740
# puri emerald bay                        0.473816
# the close north                         0.477893
# ansal heights 86                        0.481969
# umang monsoon breeze                    0.486046
# dlf the primus                          0.490122
# umang winter hills                      0.494199
# indiabulls enigma                       0.498275
# ireo the corridors                      0.502038
# mvn athens                              0.505801
# Name: proportion, dtype: float64

# %%
society_counts = df['society'].value_counts()

# Frequency distribution for societies
frequency_bins = {
    "Very High (>100)": (society_counts > 100).sum(),
    "High (50-100)": ((society_counts >= 50) & (society_counts <= 100)).sum(),
    "Average (10-49)": ((society_counts >= 10) & (society_counts < 50)).sum(),
    "Low (2-9)": ((society_counts > 1) & (society_counts < 10)).sum(),
    "Very Low (1)": (society_counts == 1).sum()
}
frequency_bins
# Out:
# {'Very High (>100)': np.int64(1),
#  'High (50-100)': np.int64(2),
#  'Average (10-49)': np.int64(92),
#  'Low (2-9)': np.int64(273),
#  'Very Low (1)': np.int64(308)}

# %%
df[df['society'] != 'independent']['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='society'>

# %%
df['society'].isnull().sum()
# Out:
# np.int64(1)

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price  price_per_sqft    area  \
# 1643          flat     NaN  sector 78    0.6          3692.0  1625.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1643  Built Up area: 1625 (150.97 sq.m.)        2         2       0       NaN
#
#              facing       agePossession  super_built_up_area  built_up_area  \
# 1643  not available  Under Construction                  NaN         1625.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1643          NaN           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 1643                1             0

# %% [markdown]
# # **Observations**
# **Around 13% properties comes under independent tag.**
#
# **1. There are 675 societies.**
#
# **2. The top 75 societies have 50 percent of the preperties and the rest 50 percent of the properties come under the remaining 600 societies**
#
# **3. Very High (>100): Only 1 society has more than 100 listings.**
#
# **4. High (50-100): 2 societies have between 50 to 100 listings.**
#
# **5. Average (10-49): 92 societies fall in this range with 10 to 49 listings each.**
#
# **6. Low (2-9): 273 societies have between 2 to 9 listings.**
#
# **7. Very Low (1): A significant number, 308 societies, have only 1 listing.**
#
# **8. 1 missing value**

# %% [markdown]
# # **3. sector**

# %%
# unique sectors
df['sector'].value_counts().shape
# Out:
# (113,)

# %%
# top 10 sectors
df['sector'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='sector'>

# %%
# Frequency distribution for sectors
sector_counts = df['sector'].value_counts()

sector_frequency_bins = {
    "Very High (>100)": (sector_counts > 100).sum(),
    "High (50-100)": ((sector_counts >= 50) & (sector_counts <= 100)).sum(),
    "Average (10-49)": ((sector_counts >= 10) & (sector_counts < 50)).sum(),
    "Low (2-9)": ((sector_counts > 1) & (sector_counts < 10)).sum(),
    "Very Low (1)": (sector_counts == 1).sum()
}

sector_frequency_bins
# Out:
# {'Very High (>100)': np.int64(3),
#  'High (50-100)': np.int64(25),
#  'Average (10-49)': np.int64(63),
#  'Low (2-9)': np.int64(21),
#  'Very Low (1)': np.int64(1)}

# %% [markdown]
# # **Observations**
# **There are a total of 104 unique sectors in the dataset.**
#
# **Frequency distribution of sectors:**
#
# **Very High (>100): 3 sectors have more than 100 listings.**
#
# **High (50-100): 25 sectors have between 50 to 100 listings**
#
# **Average (10-49): A majority, 60 sectors, fall in this range with 10 to 49 listings each.**
#
# **Low (2-9): 16 sectors have between 2 to 9 listings.**
#
# **Very Low (1): Interestingly, there are no sectors with only 1 listing.**

# %% [markdown]
# # **4. Price**

# %%
df['price'].isnull().sum()
# Out:
# np.int64(17)

# %%
df['price'].describe()
# Out:
# count    3659.000000
# mean        2.533927
# std         2.980988
# min         0.070000
# 25%         0.950000
# 50%         1.520000
# 75%         2.750000
# max        31.500000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'], kde=True, bins=50)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x=df['price'], color='lightgreen')
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# # **Descriptive Statistics:**
#
# **-> Count: There are 3,660 non-missing price entries.**
#
# **-> Mean Price: The average price is approximately 2.53 crores.**
#
# **-> Median Price: The median (or 50th percentile) price is 1.52 crores.**
#
# **-> Standard Deviation: The prices have a standard deviation of 2.98, indicating variability in the prices.**
#
# **-> Range: Prices range from a minimum of 0.07 crores to a maximum of 31.5 crores.**
#
# **-> IQR: The interquartile range (difference between 75th and 25th percentile) is from 0.95 crores to 2.75 crores.**
#
# # **Visualizations:**
#
# **-> Distribution: The histogram indicates that most properties are priced in the lower range (below 5 crores), with a few properties going beyond 10 crores.**
#
# **-> Box Plot: The box plot showcases the spread of the data and potential outliers. Properties priced above approximately 10 crores might be considered outliers as they lie beyond the upper whisker of the box plot.**
#
# **-> Missing Values: There are 17 missing values in the price column.**

# %%
# Skewness and Kurtosis
skewness = df['price'].skew()
kurtosis = df['price'].kurt()

print(skewness,kurtosis)
# Out:
# 3.278607425257671 14.92834001207525

# %% [markdown]
# **-> Skewness: The price distribution has a skewness of approximately 3.28, indicating a positive skew. This means that the distribution tail is skewed to the right, which aligns with our observation from the histogram where most properties have prices on the lower end with a few high-priced properties.**
#
# **-> Kurtosis: The kurtosis value is approximately 14.93. A kurtosis value greater than 3 indicates a distribution with heavier tails and more outliers compared to a normal distribution.**

# %%
# Quantile Analysis
quantiles = df['price'].quantile([0.01, 0.05, 0.95, 0.99])

quantiles
# Out:
# 0.01     0.250
# 0.05     0.370
# 0.95     8.500
# 0.99    15.268
# Name: price, dtype: float64

# %% [markdown]
# # **Quantile Analysis:**
#
# **-> 1% Quantile: Only 1% of properties are priced below 0.25 crores.**
#
# **-> 5% Quantile: 5% of properties are priced below 0.37 crores.**
#
# **-> 95% Quantile: 95% of properties are priced below 8.5 crores.**
#
# **-> 99% Quantile: 99% of properties are priced below 15.26 crores, indicating that very few properties are priced above this value.**

# %%
# Identify potential outliers using IQR method
Q1 = df['price'].describe()['25%']
Q3 = df['price'].describe()['75%']
IQR = Q3 - Q1

IQR
# Out:
# np.float64(1.8)

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound, upper_bound)
# Out:
# -1.7500000000000002 5.45

# %%
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
outliers.shape
# Out:
# (425, 23)

# %%
outliers['price'].describe()
# Out:
# count    425.000000
# mean       9.235624
# std        4.065259
# min        5.460000
# 25%        6.460000
# 50%        8.000000
# 75%       10.750000
# max       31.500000
# Name: price, dtype: float64

# %% [markdown]
# # **Outliers Analysis (using IQR method):**
#
# **-> Based on the IQR method, there are 425 properties considered as outliers.**
#
# **-> These outliers have an average price of approximately 9.24 crores.**
#
# **-> The range for these outliers is from 5.46 crores to 31.5 crores.**

# %%
# price binning
bins = [0, 1, 2, 3, 5, 10, 20, 50]
bin_labels = ["0-1", "1-2", "2-3", "3-5", "5-10", "10-20", "20-50"]
pd.cut(df['price'], bins=bins, labels=bin_labels, right=False).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# **-> The majority of properties are priced in the "1-2 crores" and "2-3 crores" ranges**.
#
# **-> There's a significant drop in the number of properties priced above "5 crores."**

# %%
# ecdf plot
ecdf = df['price'].value_counts().sort_index().cumsum() / len(df['price'])
plt.plot(ecdf.index, ecdf, marker='.', linestyle='none')
plt.grid()

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.histplot(df['price'], kde=True, bins=50, color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.histplot(np.log1p(df['price']), kde=True, bins=50, color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **-> np.log1p(x): This function computes the natural logarithm of 1+x. It's designed to provide more accurate results for values of x that are very close to zero.**
#
# **-> Using np.log1p helps in transforming the price column while ensuring that any value (including zero, if present) is handled appropriately. When we need to reverse the transformation, we can use np.expm1 which computes e^x-1**

# %%
skewness = np.log1p(df['price']).skew()
kurtosis = np.log1p(df['price']).kurt()

print(skewness,kurtosis)
# Out:
# 1.073781172212794 0.963437986064767

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
# plt.subplot(1, 2, 1)
# sns.boxplot(df['price'], color='skyblue')
# plt.title('Distribution of Prices (Original)')
# plt.xlabel('Price (in Crores)')
# plt.ylabel('Frequency')

sns.boxplot(x=df['price'], color='lightgreen')  # use x= for horizontal
plt.title('Floor Number Distribution')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')
plt.show()

plt.subplot(1, 2, 2)
sns.boxplot(x=np.log1p(df['price']), color='lightgreen')  # use x= for horizontal
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **5. price_per_sqft**

# %%
df['price_per_sqft'].isnull().sum()
# Out:
# np.int64(17)

# %%
df['price_per_sqft'].describe()
# Out:
# count      3659.00000
# mean      13892.73408
# std       23213.23914
# min           4.00000
# 25%        6816.50000
# 50%        9020.00000
# 75%       13883.00000
# max      600000.00000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(df['price_per_sqft'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(x=df['price_per_sqft'], color='lightgreen')  # use x= for horizontal
plt.title('price_per_sqft Distribution')
plt.xlabel('price_per_sqft')
plt.show()

# %% [markdown]
# **-> The box plot clearly shows several outliers, especially on the higher side. The interquartile range (IQR) is relatively compact, but there are many data points beyond the "whiskers" of the box plot, indicating potential outliers**
#
# **-> Observations**
#
# **-> Potential Outliers**
#
# **-> left Skewed**
#
# **-> 17 missing values**

# %% [markdown]
# # **bedRoom**

# %%
df['bedRoom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bedRoom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].value_counts(normalize=True).head(5).plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# # **bathroom**

# %%
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bathroom'>

# %%
df['bathroom'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# # **balcony**

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='balcony'>

# %%
df['balcony'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
df.iloc[:,10:].head()
# Out:
#    floorNum         facing       agePossession  super_built_up_area  \
# 0       2.0  not available        Old Property                  NaN
# 1       2.0  not available      Moderately Old                  NaN
# 2      10.0  not available  Under Construction               1337.0
# 3       1.0  not available  Under Construction                  NaN
# 4      20.0  not available        New Property                145.0
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0         1935.0          NaN           1             1           0
# 1         2430.0          NaN           0             1           0
# 2            NaN          NaN           0             1           0
# 3            NaN       2059.0           0             1           0
# 4            NaN         86.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                0            80
# 1           0       0                1            30
# 2           0       0                1            60
# 3           0       0                1            49
# 4           0       0                1            70

# %% [markdown]
# # **floorNum**

# %%
df['floorNum'].isnull().sum()
# Out:
# np.int64(19)

# %%
df['floorNum'].describe()
# Out:
# count    3657.000000
# mean        6.799289
# std         6.012948
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max        51.000000
# Name: floorNum, dtype: float64

# %%
df['floorNum'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='floorNum'>

# %%
sns.boxplot(x=df['floorNum'], color='lightgreen')  # use x= for horizontal
plt.title('Floor Number Distribution')
plt.xlabel('Floor Number')
plt.show()

# %% [markdown]
# **-> The majority of the properties lie between the ground floor (0) and the 25th floor.**
#
# **-> Floors 1 to 4 are particularly common, with the 3rd floor being the most frequent.**
#
# **-> There are a few properties located at higher floors, but their frequency is much lower.**
#
# **-> The box plot reveals that the majority of the properties are concentrated around the lower floors. The interquartile range (IQR) lies between approximately the 2nd and 10th floors.**
#
# **-> Data points beyond the "whiskers" of the box plot, especially on the higher side, indicate potential outliers.**

# %% [markdown]
# # **facing**

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['facing'].value_counts()
# Out:
# facing
# not available    1044
# North-East        623
# East              623
# North             387
# West              249
# South             231
# North-West        193
# South-East        173
# South-West        153
# Name: count, dtype: int64

# %% [markdown]
# # **agePossession**

# %%
df['agePossession'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1646
# New Property           592
# Moderately Old         563
# Undefined              446
# Old Property           303
# Under Construction     126
# Name: count, dtype: int64

# %% [markdown]
# # **areas**

# %%
# super built up area
df['super_built_up_area'].isnull().sum()
# Out:
# np.int64(1801)

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.histplot(df['super_built_up_area'].dropna(), bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
sns.boxplot(x=df['super_built_up_area'], color='lightgreen')  # use x= for horizontal
plt.title('super_built_up_area Distribution')
plt.xlabel('super_built_up_area')
plt.show()

# %% [markdown]
# **-> Most properties have a super built-up area ranging between approximately 1,000 sq.ft and 2,500 sq.ft.**
#
# **-> There are a few properties with a significantly larger area, leading to a right-skewed distribution.**
#
# **-> The interquartile range (IQR) lies between roughly 1,480 sq.ft and 2,215 sq.ft, indicating that the middle 50% of the properties fall within this range.**
#
# **-> There are several data points beyond the upper "whisker" of the box plot, indicating potential outliers. These are properties with an unusually large super built-up are**

# %% [markdown]
# # **built up area**

# %%
df['built_up_area'].isnull().sum()
# Out:
# np.int64(1987)

# %%
df['built_up_area'].describe()
# Out:
# count      1689.000000
# mean       2380.313812
# std       17948.169318
# min           2.000000
# 25%        1100.000000
# 50%        1650.000000
# 75%        2400.000000
# max      737147.000000
# Name: built_up_area, dtype: float64

# %%
sns.histplot(df['built_up_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['built_up_area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='built_up_area'>

# %% [markdown]
# # **carpet area**

# %%
df['carpet_area'].isnull().sum()
# Out:
# np.int64(1804)

# %%
df['carpet_area'].describe()
# Out:
# count      1872.000000
# mean       2529.179507
# std       22799.836449
# min          15.000000
# 25%         843.000000
# 50%        1300.000000
# 75%        1790.000000
# max      607936.000000
# Name: carpet_area, dtype: float64

# %%
sns.histplot(df['carpet_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='carpet_area', ylabel='Count'>

# %%
sns.boxplot(x=df['carpet_area'], color='lightgreen')  # use x= for horizontal
plt.title('carpet_arear Distribution')
plt.xlabel('carpet_arear')
plt.show()

# %% [markdown]
# # **additional rooms**

# %%
df[['study room','servant room','store room','pooja room','others']].isnull().sum()
# Out:
# study room      0
# servant room    0
# store room      0
# pooja room      0
# others          0
# dtype: int64

# %%
plt.figure(figsize=(15, 10))

# Create a subplot of pie charts for each room type
for idx, room in enumerate(['study room','servant room','store room','pooja room','others'], 1):
    ax = plt.subplot(2, 3, idx)
    df[room].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, ax=ax)
    plt.title(f'Distribution of {room.title()}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **furnishing_type**

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 1    2435
# 0    1038
# 2     203
# Name: count, dtype: int64

# %%
df['furnishing_type'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **luxury score**

# %%
df['luxury_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['luxury_score'].describe()
# Out:
# count    3676.000000
# mean       71.513058
# std        53.066300
# min         0.000000
# 25%        31.000000
# 50%        59.000000
# 75%       110.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.histplot(df['luxury_score'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
sns.boxplot(x=df['luxury_score'], color='lightgreen')  # use x= for horizontal
plt.title('luxury_score Distribution')
plt.xlabel('luxury_score')
plt.show()

# %% [markdown]
# # **Multi Variate Analysis**

# %% [markdown]
# # ***property_type vs price***

# %%
df.head()
# Out:
#   property_type                              society      sector  price  \
# 0         house                          independent   sector 43   5.25
# 1         house  international city by sobha phase 1  sector 109   6.10
# 2          flat                    unitech sunbreeze   sector 69   0.74
# 3          flat                      pareena mi casa   sector 68   1.90
# 4          flat                   godrej nature plus   sector 33   1.40
#
#    price_per_sqft    area                                  areaWithType  \
# 0         27132.0  1935.0                   Plot area 215(179.77 sq.m.)
# 1         25103.0  2430.0                   Plot area 270(225.75 sq.m.)
# 2          5500.0  1345.0        Super Built up area 1337(124.21 sq.m.)
# 3          9227.0  2059.0              Carpet area: 2059 (191.29 sq.m.)
# 4         15124.0   926.0  Super Built up area 145Carpet area: 86 sq.m.
#
#    bedRoom  bathroom balcony  floorNum         facing       agePossession  \
# 0        4         4       2       2.0  not available        Old Property
# 1        5         6      3+       2.0  not available      Moderately Old
# 2        3         3       1      10.0  not available  Under Construction
# 3        3         3      3+       1.0  not available  Under Construction
# 4        3         2      3+      20.0  not available        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN         1935.0          NaN           1             1
# 1                  NaN         2430.0          NaN           0             1
# 2               1337.0            NaN          NaN           0             1
# 3                  NaN            NaN       2059.0           0             1
# 4                145.0            NaN         86.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            80
# 1           0           0       0                1            30
# 2           0           0       0                1            60
# 3           0           0       0                1            49
# 4           0           0       0                1            70

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='property_type', x='price', data=df, palette='Set2')
plt.title('Price Distribution by Property Type')
plt.ylabel('Property Type')
plt.xlabel('Price')
plt.show()
# Out:
# /tmp/ipython-input-4036926611.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='property_type', x='price', data=df, palette='Set2')

# %% [markdown]
# # **property_type vs area**

# %%
df.head()
# Out:
#   property_type                              society      sector  price  \
# 0         house                          independent   sector 43   5.25
# 1         house  international city by sobha phase 1  sector 109   6.10
# 2          flat                    unitech sunbreeze   sector 69   0.74
# 3          flat                      pareena mi casa   sector 68   1.90
# 4          flat                   godrej nature plus   sector 33   1.40
#
#    price_per_sqft    area                                  areaWithType  \
# 0         27132.0  1935.0                   Plot area 215(179.77 sq.m.)
# 1         25103.0  2430.0                   Plot area 270(225.75 sq.m.)
# 2          5500.0  1345.0        Super Built up area 1337(124.21 sq.m.)
# 3          9227.0  2059.0              Carpet area: 2059 (191.29 sq.m.)
# 4         15124.0   926.0  Super Built up area 145Carpet area: 86 sq.m.
#
#    bedRoom  bathroom balcony  floorNum         facing       agePossession  \
# 0        4         4       2       2.0  not available        Old Property
# 1        5         6      3+       2.0  not available      Moderately Old
# 2        3         3       1      10.0  not available  Under Construction
# 3        3         3      3+       1.0  not available  Under Construction
# 4        3         2      3+      20.0  not available        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN         1935.0          NaN           1             1
# 1                  NaN         2430.0          NaN           0             1
# 2               1337.0            NaN          NaN           0             1
# 3                  NaN            NaN       2059.0           0             1
# 4                145.0            NaN         86.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            80
# 1           0           0       0                1            30
# 2           0           0       0                1            60
# 3           0           0       0                1            49
# 4           0           0       0                1            70

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# # **property_type vs price_per_sqft**

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['price_per_sqft'], y=df['property_type'], palette='coolwarm')
plt.title('Price per Sqft by Property Type')
plt.xlabel('Price per Sqft')
plt.ylabel('Property Type')
plt.show()
# Out:
# /tmp/ipython-input-929795955.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['price_per_sqft'], y=df['property_type'], palette='coolwarm')

# %%
df.head()
# Out:
#   property_type                              society      sector  price  \
# 0         house                          independent   sector 43   5.25
# 1         house  international city by sobha phase 1  sector 109   6.10
# 2          flat                    unitech sunbreeze   sector 69   0.74
# 3          flat                      pareena mi casa   sector 68   1.90
# 4          flat                   godrej nature plus   sector 33   1.40
#
#    price_per_sqft    area                                  areaWithType  \
# 0         27132.0  1935.0                   Plot area 215(179.77 sq.m.)
# 1         25103.0  2430.0                   Plot area 270(225.75 sq.m.)
# 2          5500.0  1345.0        Super Built up area 1337(124.21 sq.m.)
# 3          9227.0  2059.0              Carpet area: 2059 (191.29 sq.m.)
# 4         15124.0   926.0  Super Built up area 145Carpet area: 86 sq.m.
#
#    bedRoom  bathroom balcony  floorNum         facing       agePossession  \
# 0        4         4       2       2.0  not available        Old Property
# 1        5         6      3+       2.0  not available      Moderately Old
# 2        3         3       1      10.0  not available  Under Construction
# 3        3         3      3+       1.0  not available  Under Construction
# 4        3         2      3+      20.0  not available        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN         1935.0          NaN           1             1
# 1                  NaN         2430.0          NaN           0             1
# 2               1337.0            NaN          NaN           0             1
# 3                  NaN            NaN       2059.0           0             1
# 4                145.0            NaN         86.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            80
# 1           0           0       0                1            30
# 2           0           0       0                1            60
# 3           0           0       0                1            49
# 4           0           0       0                1            70

# %%
plt.figure(figsize=(10,5))
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 605          house   vatika the seven lamps   sector 82   1.60
# 650          house           dlf the arbour   sector 63   8.50
# 905          house           ats tourmaline  sector 109   1.87
# 958          house  indiabulls centrum park  sector 103   3.25
# 1198         house              independent   sector 92   1.80
# 1330         house         suncity township   sector 54   2.00
# 1375         house        suncity avenue 76   sector 76   0.75
# 1856         house      satya the hermitage  sector 103   3.15
# 2123         house              greenopolis   sector 89   0.70
# 2237         house              spaze privy   sector 72   3.10
# 2606         house               ninex city   sector 76   1.75
# 3249         house              spaze privy   sector 72   3.09
# 3271         house          godrej meridien  sector 106   5.60
# 3555         house      ireo victory valley   sector 67   8.00
#
#       price_per_sqft    area  \
# 605           6597.0  2425.0
# 650          21519.0  3950.0
# 905           8697.0  2150.0
# 958           8125.0  4000.0
# 1198          7627.0  2360.0
# 1330         30968.0   646.0
# 1375         10067.0   745.0
# 1856          6702.0  4700.0
# 2123          5397.0  1297.0
# 2237          8486.0  3653.0
# 2606          6250.0  2800.0
# 3249          6981.0  4426.0
# 3271         14000.0  4000.0
# 3555         22222.0  3600.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 605                        Plot area 2425(225.29 sq.m.)        4         4
# 650                  Built Up area: 3950 (366.97 sq.m.)        4         4
# 905                  Built Up area: 2150 (199.74 sq.m.)        3         4
# 958                        Plot area 4000(371.61 sq.m.)        4         3
# 1198                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 1330  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 1375  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 1856                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 2123                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 2237                       Plot area 3653(339.37 sq.m.)        5         5
# 2606                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 3249  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 3271                       Plot area 4000(371.61 sq.m.)        5         4
# 3555                        Plot area 400(334.45 sq.m.)        6         7
#
#      balcony  floorNum         facing   agePossession  super_built_up_area  \
# 605       3+      16.0          North  Moderately Old                  NaN
# 650       3+      27.0  not available       Undefined                  NaN
# 905        0      12.0  not available       Undefined                  NaN
# 958       3+      20.0  not available       Undefined                  NaN
# 1198       0      13.0  not available       Undefined                  NaN
# 1330       3      11.0          North  Relatively New                  NaN
# 1375       2      11.0     North-East    New Property                  NaN
# 1856       0      12.0           East       Undefined                  NaN
# 2123       2      14.0     North-East       Undefined                  NaN
# 2237      3+      21.0  not available  Relatively New                  NaN
# 2606       0      14.0  not available       Undefined                  NaN
# 3249      3+      14.0           East  Relatively New                  NaN
# 3271      3+      33.0     North-East    New Property                  NaN
# 3555      3+      51.0     North-East  Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 605          2425.0          NaN           0             1           0
# 650          3950.0          NaN           0             0           0
# 905          2150.0          NaN           0             0           0
# 958          4000.0          NaN           0             0           0
# 1198         2360.0          NaN           0             0           0
# 1330           60.0         59.0           0             1           0
# 1375          745.0          NaN           0             0           0
# 1856         4700.0          NaN           0             0           0
# 2123         1297.0          NaN           0             0           0
# 2237         3653.0          NaN           0             0           0
# 2606            NaN       2800.0           0             0           0
# 3249         3653.0       2922.0           0             1           0
# 3271         4000.0          NaN           1             1           1
# 3555         3600.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 605            0       0                1            94
# 650            0       0                1            61
# 905            0       0                1             0
# 958            0       0                1            51
# 1198           0       0                1             0
# 1330           0       0                2             7
# 1375           0       0                1            40
# 1856           0       0                1            61
# 2123           0       0                1             0
# 2237           0       0                1             0
# 2606           0       0                1             0
# 3249           0       0                0            33
# 3271           1       0                1           151
# 3555           1       0                0            49

# %%
# conclusion houses(villa) but in appartments

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# # **price**

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'], y=df['price'], hue=df['bedRoom'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'], y=df['price'], hue=df['agePossession'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['furnishing_type'].astype('category'))
plt.show()

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(x=df['luxury_score'],y=df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# # **correlation**

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
df.select_dtypes(include=np.number).corr()['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589813
# built_up_area          0.551575
# bedRoom                0.522905
# servant room           0.400897
# price_per_sqft         0.391256
# pooja room             0.341466
# store room             0.309102
# study room             0.258939
# luxury_score           0.094776
# area                   0.034713
# others                -0.003277
# carpet_area           -0.011344
# floorNum              -0.094352
# furnishing_type       -0.133385
# Name: price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3675 entries, 0 to 3801
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3675 non-null   object
#  1   society              3674 non-null   object
#  2   sector               3675 non-null   object
#  3   price                3658 non-null   float64
#  4   price_per_sqft       3658 non-null   float64
#  5   area                 3658 non-null   float64
#  6   areaWithType         3675 non-null   object
#  7   bedRoom              3675 non-null   int64
#  8   bathroom             3675 non-null   int64
#  9   balcony              3675 non-null   object
#  10  floorNum             3656 non-null   float64
#  11  facing               3675 non-null   object
#  12  agePossession        3675 non-null   object
#  13  super_built_up_area  1875 non-null   float64
#  14  built_up_area        1688 non-null   float64
#  15  carpet_area          1872 non-null   float64
#  16  study room           3675 non-null   int64
#  17  servant room         3675 non-null   int64
#  18  store room           3675 non-null   int64
#  19  pooja room           3675 non-null   int64
#  20  others               3675 non-null   int64
#  21  furnishing_type      3675 non-null   int64
#  22  luxury_score         3675 non-null   int64
# dtypes: float64(7), int64(9), object(7)
# memory usage: 689.1+ KB
